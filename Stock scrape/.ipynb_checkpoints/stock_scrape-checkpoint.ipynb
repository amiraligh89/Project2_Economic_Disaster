# %%
# Dependenceis
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

# %%
# MAC user: 
#https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
#executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
#browser = Browser('chrome', **executable_path, headless=False)

# Initialize browser
#def init_browser():
# using the output above to define our executable path with splinter
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Identifying the website to be scrapped and establishing a connection
url = 'https://www.google.com/search?q=finance&rlz=1C5CHFA_enUS840US848&oq=S%26P+live+ticker&aqs=chrome.0.0.6151j1j8&sourceid=chrome&ie=UTF-8&stick=H4sIAAAAAAAAAOPQeMSozC3w8sc9YSmpSWtOXmMU4RJyy8xLzEtO9UnMS8nMSw9ITE_lAQCCiJIYKAAAAA&tbm=fin&sa=X&ved=2ahUKEwjV7I6v65bkAhVnUd8KHSwCBZgQ6M8CMAB6BAgPEAI'
browser.visit(url)

# %%
# Creating a beautifulsoup object and parsing this object
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Scraping for the DJI, S&P, & NASDAQ trade volume and current gain/loss standing
tickers = soup.find_all('div', id = "kp-wp-tab-MARKET_SUMMARY")
print(tickers[0])
# Out:
# <div data-hveid="48" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQkt4BCDAoAA" id="kp-wp-tab-MARKET_SUMMARY" jsname="QvTDgf"><div class="xT4Cue" style="width:0"><div class="zmhDub" data-hveid="49" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQotoCCDE"><div data-hveid="50" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQo7QCCDIoAA"><div aria-level="2" class="rKFBM gsrt wp-ms" role="heading"><div class="HnYYW">You may be interested in</div></div><div class="vnLNtd mnr-c B03h3d ptcLIOszQJu__wholepage-card wp-ms" data-hveid="52"><div class="UDZeY"><div class="mod" data-md="231"><!--m--><div data-hveid="53"><div class="ML43Jb fw-wli bm7Wje" data-mid="/m/0cqyw"><g-link><a class="a-no-hover-decoration" href="/search?sa=X&amp;rlz=1C5CHFA_enUS840US848&amp;tbm=fin&amp;q=INDEXDJX:+.DJI&amp;stick=H4sIAAAAAAAAAONgecRozC3w8sc9YSmtSWtOXmNU4eIKzsgvd80rySypFBLjYoOyeKS4uDj0c_UNkgsry3kWsfJ5-rm4Rrh4RVgp6Ll4eQIAqJT5uUkAAAA&amp;ved=0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQlq4CCDYwAA"><div class="ML43Jb CPqeke"><span class="z4Fov">Dow Jones Industrial Average</span><span class="kbeSId"><span class="j7FfMb">.DJI</span><span class
">+18.78 </span><span aria-label="Up by 0.65%"><span aria-hidden="true" class="ipWPwgofNihU-Y5HEJA6AmUY">(0.65%)</span></span></span></span></div></a></g-link><span aria-pressed="false" class="zObCod qFZzRe" data-mid="/m/016yss" jsaction="rcuQ6b:npT2md;KjsqPd" jscontroller="YrCB3e" role="button" tabindex="0"> <div aria-label="Follow" class="A7dSX" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQ0d4DCDwwAA" jsname="ry7ugf"><span class="z1asCe vX33ce" style="height:14px;line-height:14px;width:14px"><svg focusable="false" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d="M19 13h-6v6h-2v-6H5v-2h6V5h2v6h6v2z"></path></svg></span></div><div aria-label="Un ...
# Does Business. Here's Why It's ...</div></div><div class="tYlW7b"><span class="wqg8ad">Inc.</span><span class="kxJ65e">·</span><span class="K4LhXb"><span class="FGlSad"><span>13 hours ago</span></span></span></div></div></div></a><div></div></div></div></g-inner-card></div><div class="bh13Qc nuboAb"><g-inner-card class="cv2VAd"><div><div class="dbsr" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQxPQBCFgoBDAF"><a data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQxfQBCFkwBQ" href="https://theweek.com/speedreads/861627/warren-buffett-hasnt-stockpiled-much-cash-since-right-before-financial-crisis" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://theweek.com/speedreads/861627/warren-buffett-hasnt-stockpiled-much-cash-since-right-before-financial-crisis&amp;ved=0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQxfQBCFkwBQ"><div class="P5BnJb"><div class="pP3ABc"><div class="hutKRb" style="width:137px"><div class="qV9w7d" style="height:77px"><div class="KNcnob" style="height:77px;width:137px;background-color:#0a0907"><g-img><img alt="" class="rISBZc M4dUYb" data-atf="3" height="77" id="dimg_9" src="data:image/jpeg;base64,..." width="137"/></g-img></div></div></div></div><div class="Od9uAe"><div class="y9oXvf" style="-webkit-line-clamp:2"><div class="nDgy9d" style="-webkit-line-clamp:2">Warren Buffett hasn't stockpiled this much cash since right before the
# financial crisis</div></div><div class="tYlW7b"><span class="wqg8ad">The Week</span><span class="kxJ65e">·</span><span class="K4LhXb"><span class="FGlSad"><span>9 hours ago</span></span></span></div></div></div></a><div></div></div></div></g-inner-card></div></div><script nonce="GrqfDn8M1RT+L5T8l3gCNw==">(function(){var a=document.querySelector("#taw"),b=document.querySelector("#topstuff");if(a&&!a.clientHeight&&b&&!b.clientHeight)for(var c=document.querySelector("#rso").children,d=0;d<c.length;++d)if(0<c[d].clientHeight){var e=c[d].querySelector("div g-section-with-header");e&&(e.style.marginTop=0);break};}).call(this);</script></g-section-with-header></div><div class="AZir3d"><a class="sxR6Tb oRJe3d r-ijROUTmn3JTs" data-rtid="ijROUTmn3JTs" data-ved="0ahUKEwjH1dSk4KbkAhWIv1kKHcNWAawQwfoBCFw" jsaction="r.VIpruVBnF98" jsl="$t t-dSwcoYVP8xE;$x 0;" role="link" tabindex="0"> <span class="fdHGEc">More about top stories</span><span class="wOdj7e z1asCe lYxQe" style="height:16px;line-height:16px;width:16px"><svg focusable="false" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg"><path d
><div class="P5BnJb"><div class="pP3ABc"><div class="hutKRb" style="width:137px"><div class="qV9w7d" style="height:77px"><div class="KNcnob" style="height:77px;width:137px;background-color:#f7f9f9"><g-img><img alt="" class="rISBZc M4dUYb" data-atf="3" height="77" id="dimg_13" src="data:image/jpeg;base64,..." width="137"/></g-img></div></div></div></div><div class="Od9uAe"><div class="y9oXvf" style="-webkit-line-clamp:2"><div class="nDgy9d" style="-webkit-line-clamp:2">Goldman Sachs: 5 ‘Strong Buy’ Stocks To Beat Market Volatility</div></div><div class="tYlW7b"><span class="wqg8ad">Yahoo Finance</span><span class="kxJ65e">·</span><span class="K4LhXb">< ...

# %%
long_names = soup.find_all('span', class_ = "z4Fov")
shares_traded = soup.find_all('span', class_ = "Z90tFb")
changes = soup.find_all('span', class_ = "hO8Bcf")
print(long_names[0].text)
print(shares_traded[0].text)
print(changes[0].text)
# Out:
# Dow Jones Industrial Average
# 26,036.10
# +258.20 (1.00%)

# %%
len(long_names)
# Out:
# 19

# %%
len(shares_traded)
# Out:
# 19

# %%
for x in range(len(long_names)):
    print(long_names[x].text, shares_traded[x].text, changes[x].text)
# Out:
# Dow Jones Industrial Average 26,036.10 +258.20 (1.00%)
# S&P 500 Index 2,887.94 +18.78 (0.65%)
# Amazon.com, Inc. 1,764.25 USD +2.42 (0.14%)
# Dow Jones Industrial Average 26,036.10 +258.20 (1.00%)
# S&P 500 Index 2,887.94 +18.78 (0.65%)
# Nasdaq Composite 7,856.88 +29.94 (0.38%)
# Russell 2000 Index 1,472.71 +16.67 (1.15%)
# Dow Jones Industrial Average 26,036.10 +258.20 (1.00%)
# DAX PERFORMANCE-INDEX 11,701.02 −29.00 (0.25%)
# BSE SENSEX 37,451.84 −189.43 (0.50%)
# FTSE 100 Index 7,114.71 +25.13 (0.35%)
# IBEX 35 8,747.10 +18.20 (0.21%)
# Closed: 11:46 PM UTC 1.11 −0.00082 (0.074%)
# Closed: 11:45 PM UTC 106.05 +0.30 (0.29%)
# Closed: 11:45 PM UTC 1.22 −0.0064 (0.52%)
# Closed: 11:47 PM UTC 1.33 +0.0022 (0.17%)
# Closed: 11:46 PM UTC 7.84 −0.0035 (0.045%)
# Closed: 10:00 PM UTC 7.17 +0.0029 (0.040%)
# Closed: 11:45 PM UTC 0.67 −0.0016 (0.23%)

# %%
print(long_names[0].text, shares_traded[0].text, changes[0].text)
print(long_names[1].text, shares_traded[1].text, changes[1].text)
print(long_names[5].text, shares_traded[5].text, changes[5].text)
print(long_names[6].text, shares_traded[6].text, changes[6].text)
# Out:
# Dow Jones Industrial Average 26,036.10 +258.20 (1.00%)
# S&P 500 Index 2,887.94 +18.78 (0.65%)
# Nasdaq Composite 7,856.88 +29.94 (0.38%)
# Russell 2000 Index 1,472.71 +16.67 (1.15%)
